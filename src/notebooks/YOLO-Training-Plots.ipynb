# %%
import matplotlib.pyplot as plt

# %%
# 9 layers, l2 loss, gamma 1
plt.figure()
plt.xlabel("epochs")
plt.ylabel("validation mAP")
# plt.title(r"9 layers regularization, $\gamma$ = 1.0")
plt.plot([0.053, 0.089, 0.113, 0.140, 0.138, 0.153, 0.172, 0.172, 0.170, 0.160, 0.165, 0.162, 0.187, 0.170, 0.188, 0.183, 0.191, 0.178, 0.190, 0.133, 0.202, 0.204, 0.200, 0.181, 0.199, 0.198, 0.194, 0.187, 0.166, 0.198], label='Original data')
plt.plot([0.038, 0.068, 0.088, 0.110, 0.110, 0.121, 0.139, 0.137, 0.136, 0.119, 0.137, 0.128, 0.144, 0.142, 0.120, 0.117, 0.164, 0.151, 0.107, 0.066, 0.148, 0.136, 0.110, 0.110, 0.145, 0.119, 0.114, 0.114, 0.097, 0.117], label='Adversarial examples, FGSM eps=2')
plt.legend(loc='best', fontsize=10)
plt.show()

# %%
# 2 layers, l2 loss, gamma 1
plt.figure()
plt.xlabel("epochs")
plt.ylabel("validation mAP")
# plt.title(r"2 layers regularization, $\gamma$ = 1.0")
plt.plot([0.093, 0.119, 0.151, 0.163, 0.166, 0.177, 0.190, 0.198, 0.204, 0.207, 0.203, 0.214, 0.215, 0.212, 0.222, 0.220, 0.223, 0.220, 0.222, 0.230, 0.242, 0.232, 0.220, 0.222, 0.243, 0.237, 0.244, 0.234, 0.225, 0.228, 0.238, 0.239, 0.236, 0.248, 0.230, 0.248], label='Original data')
plt.plot([0.067, 0.086, 0.108, 0.119, 0.124, 0.136, 0.142, 0.149, 0.152, 0.153, 0.151, 0.158, 0.159, 0.153, 0.165, 0.160, 0.162, 0.162, 0.148, 0.165, 0.183, 0.166, 0.162, 0.159, 0.155, 0.152, 0.161, 0.154, 0.147, 0.143, 0.141, 0.147, 0.143, 0.149, 0.138, 0.154], label='Adversarial examples, FGSM eps=2')
plt.legend(loc='best', fontsize=10)
plt.show()

# %%
# 2 layers, interval 3
plt.figure()
plt.xlabel("epochs")
plt.ylabel("validation mAP")
# plt.title(r"2 layers regularization, $\gamma$ = 1.0, alternating loss")
plt.plot([0.130, 0.159, 0.144, 0.183, 0.186, 0.170, 0.201, 0.224, 0.192, 0.241, 0.247, 0.208, 0.248, 0.263, 0.226, 0.264, 0.266, 0.224, 0.272, 0.268, 0.228, 0.269, 0.263, 0.235, 0.268, 0.273, 0.246, 0.270, 0.275, 0.255, 0.257, 0.272, 0.248, 0.258, 0.267, 0.253, 0.263, 0.262, 0.251],  label='Original data')
plt.plot([0.041, 0.050, 0.104, 0.065, 0.070, 0.122, 0.078, 0.092, 0.136, 0.101, 0.100, 0.146, 0.113, 0.117, 0.159, 0.124, 0.121, 0.153, 0.127, 0.119, 0.161, 0.121, 0.113, 0.155, 0.137, 0.127, 0.162, 0.126, 0.138, 0.169, 0.137, 0.141, 0.172, 0.132, 0.137, 0.167, 0.145, 0.137, 0.166], label='Adversarial examples, FGSM eps=2')
plt.legend(loc='best', fontsize=10)
plt.show()

# %%
# 2 layers, l1 loss
plt.figure()
plt.xlabel("epochs")
plt.ylabel("validation mAP")
# plt.title(r"9 layers regularization, $\gamma$ = 1.0")
plt.plot([0.035, 0.067, 0.099, 0.109, 0.135, 0.147, 0.172, 0.189, 0.187, 0.194, 0.196, 0.204, 0.218, 0.212, 0.204, 0.217, 0.209, 0.208, 0.220, 0.220, 0.228, 0.227, 0.226],  label='Original data')
plt.plot([0.021, 0.044, 0.068, 0.074, 0.100, 0.108, 0.127, 0.140, 0.136, 0.146, 0.144, 0.149, 0.157, 0.156, 0.150, 0.139, 0.148, 0.137, 0.164, 0.156, 0.165, 0.163, 0.161], label='Adversarial examples, FGSM eps=2')
plt.legend(loc='best', fontsize=10)
plt.show()

# %%
# l2 loss + interval 2
plt.figure()
plt.xlabel("epochs")
plt.ylabel("validation mAP")
# plt.title(r"9 layers regularization, $\gamma$ = 1.0")
plt.plot([0.108, 0.119, 0.154, 0.149, 0.185, 0.187, 0.210, 0.201, 0.230, 0.214, 0.228, 0.215, 0.240, 0.234, 0.246, 0.220, 0.260], label='Original data')
plt.plot([0.028, 0.086, 0.055, 0.106, 0.073, 0.137, 0.084, 0.142, 0.109, 0.151, 0.111, 0.156, 0.113, 0.169, 0.12, 0.152, 0.121], label='Adversarial examples, FGSM eps=2')
plt.legend(loc='best', fontsize=10)
plt.show()

# %%
# l2 loss + gamma log10
plt.figure()
plt.xlabel("epochs")
plt.ylabel("validation mAP")
# plt.title(r"9 layers regularization, $\gamma$ = 1.0")
plt.plot([0.094, 0.128, 0.131, 0.161, 0.166, 0.181, 0.184, 0.200, 0.198, 0.195, 0.207, 0.220], label='Original data')
plt.plot([0.064, 0.090, 0.096, 0.119, 0.122, 0.138, 0.134, 0.147, 0.146, 0.144, 0.154, 0.166], label='Adversarial examples, FGSM eps=2')
plt.legend(loc='best', fontsize=10)
plt.show()

# %%
plt.figure()
# plt.plot([0.038, 0.068, 0.088, 0.110, 0.110, 0.121, 0.139, 0.137, 0.136, 0.119, 0.137, 0.128, 0.144, 0.142, 0.120, 0.117, 0.164, 0.151, 0.107, 0.066, 0.148, 0.136, 0.110, 0.110, 0.145, 0.119, 0.114, 0.114, 0.097, 0.117], label='l2 loss + 9 layers')
plt.plot([0.067, 0.086, 0.108, 0.119, 0.124, 0.136, 0.142, 0.149, 0.152, 0.153, 0.151, 0.158, 0.159, 0.153, 0.165, 0.160, 0.162, 0.162, 0.148, 0.165, 0.183, 0.166, 0.162, 0.159, 0.155, 0.152, 0.161, 0.154, 0.147, 0.143, 0.141, 0.147, 0.143, 0.149, 0.138, 0.154], label='l2 loss + 2 layers')
plt.plot([0.041, 0.050, 0.104, 0.065, 0.070, 0.122, 0.078, 0.092, 0.136, 0.101, 0.100, 0.146, 0.113, 0.117, 0.159, 0.124, 0.121, 0.153, 0.127, 0.119, 0.161, 0.121, 0.113, 0.155, 0.137, 0.127, 0.162, 0.126, 0.138, 0.169, 0.137, 0.141, 0.172, 0.132, 0.137], label='l2 loss + 2 layers + interval3')
# plt.plot([0.021, 0.044, 0.068, 0.074, 0.100, 0.108, 0.127, 0.140, 0.136, 0.146, 0.144, 0.149, 0.157, 0.156, 0.150, 0.139, 0.148, 0.137, 0.164, 0.156, 0.166], label='l1 loss + 2 layers')
plt.plot([0.028, 0.086, 0.055, 0.106, 0.073, 0.137, 0.084, 0.142, 0.109, 0.151, 0.111, 0.156, 0.113, 0.169], label='l2 loss + 2 layers + interval 2')
# plt.plot([0.064, 0.090, 0.096, 0.119, 0.122, 0.138, 0.134, 0.147, 0.146, 0.144], label='l2 loss + 2 layers + gamma schedule log')

plt.legend(loc='best', fontsize=10)
plt.show()
